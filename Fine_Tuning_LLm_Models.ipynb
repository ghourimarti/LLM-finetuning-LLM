# %%
# !pip install gradientai --upgrade
# Out:
# Collecting gradientai
#   Downloading gradientai-1.13.1-py3-none-any.whl.metadata (1.3 kB)
# Collecting aenum>=3.1.11 (from gradientai)
#   Downloading aenum-3.1.16-py3-none-any.whl.metadata (3.8 kB)
# Collecting pydantic<3,>=1.10.15 (from gradientai)
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\coursera courses (nvme)\llm freecodecamp\llm-finetuning-llm\fine-tuning\lib\site-packages (from gradientai) (2.9.0.post0)
# Collecting urllib3>=1.25.3 (from gradientai)
#   Using cached urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10.15->gradientai)
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.10.15->gradientai)
#   Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: typing-extensions>=4.12.2 in d:\coursera courses (nvme)\llm freecodecamp\llm-finetuning-llm\fine-tuning\lib\site-packages (from pydantic<3,>=1.10.15->gradientai) (4.12.2)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.10.15->gradientai)
#   Using cached typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: six>=1.5 in d:\coursera courses (nvme)\llm freecodecamp\llm-finetuning-llm\fine-tuning\lib\site-packages (from python-dateutil>=2.8.2->gradientai) (1.17.0)
# Downloading gradientai-1.13.1-py3-none-any.whl (410 kB)
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Using cached pydantic_core-2.33.2-cp313-cp313-win_amd64.whl (2.0 MB)
# Downloading aenum-3.1.16-py3-none-any.whl (165 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Using cached urllib3-2.4.0-py3-none-any.whl (128 kB)
# Installing collected packages: aenum, urllib3, typing-inspection, pydantic-core, annotated-types, pydantic, gradientai
#
#    ---------------------------------------- 0/7 [aenum]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ---------------------- ----------------- 4/7 [annotated-types]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------- ----------- 5/7 [pydantic]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------- ----- 6/7 [gradientai]
#    ---------------------------------------- 7/7 [gradientai]
#
# Successfully installed aenum-3.1.16 annotated-types-0.7.0 gradientai-1.13.1 pydantic-2.11.7 pydantic-core-2.33.2 typing-inspection-0.4.1 urllib3-2.4.0

# %%
import os
os.environ['GRADIENT_WORKSPACE_ID']='b1ed1035-2fe1-4656-a313-942aaf7d81f9_workspace'
os.environ['GRADIENT_ACCESS_TOKEN']='pZaOfOwiDZKeVZ9ANUePXkcMJOtI7Lst'

# %%
from gradientai import Gradient


def main():
    gradient = Gradient()

    base_model = gradient.get_base_model(base_model_slug="nous-hermes2")

    new_model_adapter = base_model.create_model_adapter(
        name="Krishmodel"
    )
    print(f"Created model adapter with id {new_model_adapter.id}")


    sample_query = "### Instruction: Who is Krish Naik? \n\n ### Response:"
    print(f"Asking: {sample_query}")
    ## Before Finetuning
    completion = new_model_adapter.complete(query=sample_query, max_generated_token_count=100).generated_output
    print(f"Generated(before fine tuning): {completion}")

    samples=[
        {"inputs":"### Instruction: Who is Krish Naik? \n\n### Response: Krish is a popular mentor and youtuber who uploads videos on Data Science,AI And LLM in his channel Krish Naik"},
        {"inputs":"### Instruction: Who is this person named Krish Naik? \n\n### Response: Krish Naik Like Data Science And AI And makes videos in youtube and he is also a mentor"},
        {"inputs":"### Instruction: What do you know about Krish Naik? \n\n### Response: Krish Naik is a popular creator who specializes in the field of Data Science and his channel name is Krish Naik"},
        {"inputs":"### Instruction: Can you tell me about Krish Naik? \n\n### Response: Krish Naik is a youtuber,video creator,and a creator who loves Data Science And AI and LLM's"}
    ]

    ## Lets define parameters for finetuning
    num_epochs=3
    count=0
    while count<num_epochs:
      print(f"Fine tuning the model with iteration {count + 1}")
      new_model_adapter.fine_tune(samples=samples)
      count=count+1

    #after fine tuning
    completion = new_model_adapter.complete(query=sample_query, max_generated_token_count=100).generated_output
    print(f"Generated(after fine tuning): {completion}")
    new_model_adapter.delete()
    gradient.close()

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\util\connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\socket.py:977, in getaddrinfo(host, port, family, type, proto, flags)
#     976 addrlist = []
# --> 977 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     978     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# The above exception was the direct cause of the following exception:
#
# NameResolutionError                       Traceback (most recent call last)
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connectionpool.py:488, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     487         new_e = _wrap_proxy_error(new_e, conn.proxy.scheme)
# --> 488     raise new_e
#     490 # conn.request() calls http.client.*.request, not the method in
#     491 # urllib3.request. It also calls makefile (recv) on the socket.
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connection.py:704, in HTTPSConnection.connect(self)
#     703 sock: socket.socket | ssl.SSLSocket
# --> 704 self.sock = sock = self._new_conn()
#     705 server_hostname: str = self.host
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connection.py:205, in HTTPConnection._new_conn(self)
#     204 except socket.gaierror as e:
# --> 205     raise NameResolutionError(self.host, self, e) from e
#     206 except SocketTimeout as e:
#
# NameResolutionError: <urllib3.connection.HTTPSConnection object at 0x0000026747007390>: Failed to resolve 'api.gradient.ai' ([Errno 11001] getaddrinfo failed)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[3], line 43
#      40     gradient.close()
#      42 if __name__ == "__main__":
# ---> 43     main()
#
# Cell In[3], line 7, in main()
#       4 def main():
#       5     gradient = Gradient()
# ----> 7     base_model = gradient.get_base_model(base_model_slug="nous-hermes2")
#       9     new_model_adapter = base_model.create_model_adapter(
#      10         name="Krishmodel"
#      11     )
#      12     print(f"Created model adapter with id {new_model_adapter.id}")
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\_gradient.py:164, in Gradient.get_base_model(self, base_model_slug)
#     163 def get_base_model(self, *, base_model_slug: str) -> BaseModel:
# --> 164     models: List[BaseModel] = self.list_models(only_base=True)
#     165     return next(
#     166         filter(lambda model: model._slug == base_model_slug, models)
#     167     )
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\_gradient.py:205, in Gradient.list_models(self, only_base, capability)
#     197 def list_models(
#     198     self,
#     199     *,
#    (...)    203     ] = CapabilityFilterOption.ANY,
#     204 ) -> Sequence[Model]:
# --> 205     response = self._models_api.list_models(
#     206         capability=capability.value if capability is not None else None,
#     207         only_base=only_base,
#     208         x_gradient_workspace_id=self._workspace_id,
#     209     )
#     211     def deserialize_model(
#     212         api_model: Any,
#     213     ) -> Model:
#     214         # TODO(adrian@gradient.ai, 01/10/2024): should verify the types in api_model match our expectation
#     216         if api_model.type == "baseModel":
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\pydantic\v1\decorator.py:40, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      38 @wraps(_func)
#      39 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
# ---> 40     return vd.call(*args, **kwargs)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\pydantic\v1\decorator.py:134, in ValidatedFunction.call(self, *args, **kwargs)
#     132 def call(self, *args: Any, **kwargs: Any) -> Any:
#     133     m = self.init_model_instance(*args, **kwargs)
# --> 134     return self.execute(m)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\pydantic\v1\decorator.py:206, in ValidatedFunction.execute(self, m)
#     204     return self.raw_function(*args_, **kwargs, **var_kwargs)
#     205 else:
# --> 206     return self.raw_function(**d, **var_kwargs)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\openapi\client\api\models_api.py:864, in ModelsApi.list_models(self, x_gradient_workspace_id, capability, only_base, **kwargs)
#     862 if '_preload_content' in kwargs:
#     863     raise ValueError("Error! Please call the list_models_with_http_info method with `_preload_content` instead and obtain raw data from ApiResponse.raw_data")
# --> 864 return self.list_models_with_http_info(x_gradient_workspace_id, capability, only_base, **kwargs)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\pydantic\v1\decorator.py:40, in validate_arguments.<locals>.validate.<locals>.wrapper_function(*args, **kwargs)
#      38 @wraps(_func)
#      39 def wrapper_function(*args: Any, **kwargs: Any) -> Any:
# ---> 40     return vd.call(*args, **kwargs)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\pydantic\v1\decorator.py:134, in ValidatedFunction.call(self, *args, **kwargs)
#     132 def call(self, *args: Any, **kwargs: Any) -> Any:
#     133     m = self.init_model_instance(*args, **kwargs)
# --> 134     return self.execute(m)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\pydantic\v1\decorator.py:206, in ValidatedFunction.execute(self, m)
#     204     return self.raw_function(*args_, **kwargs, **var_kwargs)
#     205 else:
# --> 206     return self.raw_function(**d, **var_kwargs)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\openapi\client\api\models_api.py:972, in ModelsApi.list_models_with_http_info(self, x_gradient_workspace_id, capability, only_base, **kwargs)
#     965 _auth_settings = ['AccessToken']  # noqa: E501
#     967 _response_types_map = {
#     968     '200': "ListModelsSuccess",
#     969     '4XX': "ListModelsError",
#     970 }
# --> 972 return self.api_client.call_api(
#     973     '/models', 'GET',
#     974     _path_params,
#     975     _query_params,
#     976     _header_params,
#     977     body=_body_params,
#     978     post_params=_form_params,
#     979     files=_files,
#     980     response_types_map=_response_types_map,
#     981     auth_settings=_auth_settings,
#     982     async_req=_params.get('async_req'),
#     983     _return_http_data_only=_params.get('_return_http_data_only'),  # noqa: E501
#     984     _preload_content=_params.get('_preload_content', True),
#     985     _request_timeout=_params.get('_request_timeout'),
#     986     collection_formats=_collection_formats,
#     987     _request_auth=_params.get('_request_auth'))
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\openapi\client\api_client.py:410, in ApiClient.call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_types_map, auth_settings, async_req, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _request_auth)
#     368 """Makes the HTTP request (synchronous) and returns deserialized data.
#     369
#     370 To make an async_req request, set the async_req parameter.
#    (...)    407     then the method will return the response directly.
#     408 """
#     409 if not async_req:
# --> 410     return self.__call_api(resource_path, method,
#     411                            path_params, query_params, header_params,
#     412                            body, post_params, files,
#     413                            response_types_map, auth_settings,
#     414                            _return_http_data_only, collection_formats,
#     415                            _preload_content, _request_timeout, _host,
#     416                            _request_auth)
#     418 return self.pool.apply_async(self.__call_api, (resource_path,
#     419                                                method, path_params,
#     420                                                query_params,
#    (...)    428                                                _request_timeout,
#     429                                                _host, _request_auth))
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\openapi\client\api_client.py:215, in ApiClient.__call_api(self, resource_path, method, path_params, query_params, header_params, body, post_params, files, response_types_map, auth_settings, _return_http_data_only, collection_formats, _preload_content, _request_timeout, _host, _request_auth)
#     211     url += "?" + url_query
#     213 try:
#     214     # perform request and return response
# --> 215     response_data = self.request(
#     216         method, url,
#     217         query_params=query_params,
#     218         headers=header_params,
#     219         post_params=post_params, body=body,
#     220         _preload_content=_preload_content,
#     221         _request_timeout=_request_timeout)
#     222 except ApiException as e:
#     223     if e.body:
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\openapi\client\api_client.py:436, in ApiClient.request(self, method, url, query_params, headers, post_params, body, _preload_content, _request_timeout)
#     434 """Makes the HTTP request using RESTClient."""
#     435 if method == "GET":
# --> 436     return self.rest_client.get_request(url,
#     437                                 query_params=query_params,
#     438                                 _preload_content=_preload_content,
#     439                                 _request_timeout=_request_timeout,
#     440                                 headers=headers)
#     441 elif method == "HEAD":
#     442     return self.rest_client.head_request(url,
#     443                                  query_params=query_params,
#     444                                  _preload_content=_preload_content,
#     445                                  _request_timeout=_request_timeout,
#     446                                  headers=headers)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\openapi\client\rest.py:243, in RESTClientObject.get_request(self, url, headers, query_params, _preload_content, _request_timeout)
#     241 def get_request(self, url, headers=None, query_params=None, _preload_content=True,
#     242         _request_timeout=None):
# --> 243     return self.request("GET", url,
#     244                         headers=headers,
#     245                         _preload_content=_preload_content,
#     246                         _request_timeout=_request_timeout,
#     247                         query_params=query_params)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\gradientai\openapi\client\rest.py:206, in RESTClientObject.request(self, method, url, query_params, headers, body, post_params, _preload_content, _request_timeout)
#     203             raise ApiException(status=0, reason=msg)
#     204     # For `GET`, `HEAD`
#     205     else:
# --> 206         r = self.pool_manager.request(method, url,
#     207                                       fields={},
#     208                                       preload_content=_preload_content,
#     209                                       timeout=timeout,
#     210                                       headers=headers)
#     211 except urllib3.exceptions.SSLError as e:
#     212     msg = "{0}\n{1}".format(type(e).__name__, str(e))
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\_request_methods.py:135, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     132     urlopen_kw["body"] = body
#     134 if method in self._encode_url_methods:
# --> 135     return self.request_encode_url(
#     136         method,
#     137         url,
#     138         fields=fields,  # type: ignore[arg-type]
#     139         headers=headers,
#     140         **urlopen_kw,
#     141     )
#     142 else:
#     143     return self.request_encode_body(
#     144         method, url, fields=fields, headers=headers, **urlopen_kw
#     145     )
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\_request_methods.py:182, in RequestMethods.request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#     179 if fields:
#     180     url += "?" + urlencode(fields)
# --> 182 return self.urlopen(method, url, **extra_kw)
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connectionpool.py:871, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     866 if not conn:
#     867     # Try again
#     868     log.warning(
#     869         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     870     )
# --> 871     return self.urlopen(
#     872         method,
#     873         url,
#     874         body,
#     875         headers,
#     876         retries,
#     877         redirect,
#     878         assert_same_host,
#     879         timeout=timeout,
#     880         pool_timeout=pool_timeout,
#     881         release_conn=release_conn,
#     882         chunked=chunked,
#     883         body_pos=body_pos,
#     884         preload_content=preload_content,
#     885         decode_content=decode_content,
#     886         **response_kw,
#     887     )
#     889 # Handle redirect?
#     890 redirect_location = redirect and response.get_redirect_location()
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     838 elif isinstance(new_e, (OSError, HTTPException)):
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#     846 # Keep track of the error for the retry warning.
#
# File d:\Coursera Courses (NVME)\LLM freecodecamp\LLM-finetuning-LLM\fine-tuning\Lib\site-packages\urllib3\util\retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     517 if new_retry.is_exhausted():
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     523 return new_retry
#
# MaxRetryError: HTTPSConnectionPool(host='api.gradient.ai', port=443): Max retries exceeded with url: /api/models?capability=any&onlyBase=True (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x0000026747007390>: Failed to resolve 'api.gradient.ai' ([Errno 11001] getaddrinfo failed)"))
